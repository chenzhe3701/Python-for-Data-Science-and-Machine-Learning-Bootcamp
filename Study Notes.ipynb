# %%
from collections import Counter 
from collections import defaultdict 
from collections import namedtuple
import os
import shutil
import datetime
import math
import random
import pdb
import re
import timeit
import zipfile
import requests
import bs4
from PIL import Image

'''
os.getcwd()
os.listdir()
os.walk()
shutil.move()
datetime.date()
datetime.time()
datetime.datetime.today()
random.seed()
random.randint()
random.choice()
random.choices()
random.sample()
random.shuffle()
random.uniform()
random.gauss()
pdb.set_trace()
re.search()
re.findall()
re.finditer()
re.compile()
timeit.timeit()
shutil.make_archive()
shutil.unpack_archive()
'''

# print method, value:width.precision
a = 3.1415926
print('{0:5.3f}'.format(a)) # ''.format() method
print(f'{a:5.3}') # f-strings, precision refers to the total number of digits
print(f'{a:5.3f}') # can use .format() syntax inside f-string

# lambda function
a = [1,2,3]
list(map(lambda x: x+1, a)) # combine map and lambda

# decorator
def mydec(inputfun):
    def mywrap(*args, **kwargs):
        myoutput = inputfun(*args, **kwargs)
        print('after decorated function')
        return myoutput
    return mywrap

myprint = mydec(print)
mysum = mydec(sum)

# web scraping
re = requests.get('http://www.example.com')
text = bs4.BeautifulSoup(re.text)
text.select('h1')[0].get_text()
# Out:
# 3.142
#  3.14
# 3.142
# 'Example Domain'

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import clear_output
# %matplotlib inline

np.array([1,2])
a = np.array([[1,2],[3,4]])
np.arange(0,10,2)
np.zeros((3,3))
np.ones((3,3))
np.eye(3)
np.linspace(0,10,11)
np.random.seed(101)
np.random.rand(2)
np.random.rand(3,3)
np.random.randn(2)
np.random.randint(1,100)
a.reshape(2,2)
np.reshape(a,(2,2))
a.max()
a.argmax()
a.min()
np.argmin(a)
np.sqrt(a)
np.exp(a)
np.max(a)
np.sin(a)
np.log(a)

labels = ['a','b','c']
lst = [10,20,30]
arr = np.array([10,20,30])
d = {'a':10,'b':20,'c':30}

ser = pd.Series(data=lst,index=labels)
df = pd.DataFrame(data=np.random.randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())
df['W']
df.drop('W',axis=1,inplace=False)
df.loc[['A','C']]
df.loc['A','W']
df.iloc[0,0]
df[df>0]
df[df['W']>0.5]
df.reset_index()
df.reset_index().set_index('index').index

outside = ['A','A','A','B','B','B']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
df = pd.DataFrame(np.random.randn(6,2), index=hier_index,columns=['X','Y'])
df.loc['A'].loc[1]
df.xs('A')
df.xs(('A',1))
df.index.names = ['Lv1','Lv2']
df.xs(1,level='Lv2')
df.dropna(axis=1,thresh=2)
df.fillna(value='Fill Value')
df.groupby('Y')
df.describe()

pd.concat([df,df],axis=1)
pd.merge(df,df,how='inner',on='X')

df = pd.DataFrame(data = np.arange(0,6).reshape(3,2), index = 'A B C'.split(), columns = 'X Y'.split())
df2 = pd.DataFrame(data = np.arange(0,6).reshape(3,2), index = 'A B C'.split(), columns = 'Z W'.split())
df.join(df2,how='inner')

df.head()
df['X'].unique()
df.loc['A'].nunique()
df['X'].value_counts()
df.apply(lambda x: x+10)
df['X'].sum()
df.columns
df.index[0]
df.sort_values(by='X',ascending=False)
df.pivot_table(values='X',index='Y',columns='X')

tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')

# sns.histplot(tips['tip']) # histogram
# sns.distplot(tips['tip'],kde=True)
# sns.jointplot(data=tips,x='total_bill',y='tip',kind='reg') # this is to match up two histograms for bivariate data
# sns.pairplot(tips,hue='sex',palette='magma') # pairwise relationship across an entire dataframe
# sns.rugplot(tips['tip'])
# sns.kdeplot(tips['tip'])

# sns.countplot(data=tips,x='sex')
# sns.barplot(data=tips,x='sex',y='tip') # aggregate categorical data based off some function, by default the mean
# sns.boxplot(data=tips,x='day',y='total_bill',palette='viridis',hue='sex')
# sns.violinplot(data=tips,x='day',y='total_bill',hue='sex',split=True)
# sns.stripplot(data=tips,x='day',y='tip',hue='sex',dodge=True)
# sns.swarmplot(data=tips,x='day',y='tip')
# sns.catplot(data=tips,x='day',y='tip',kind='bar')

# sns.heatmap(tips.corr(),cmap='magma',annot=True)
# sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))

# Grids are general typoes of plots to map plot types to rows and columns
# g = sns.PairGrid(tips) # subplot grid for plotting pariwise relationships in a dataset
# g.map(plt.scatter)
# g.map_diag(plt.hist)
# g.map_upper(plt.scatter)
# g.map_lower(sns.kdeplot)

# g = sns.FacetGrid(data=tips,col='time',row='smoker',hue='sex') # general way to create grids of plots based off a feature
# g.map(plt.hist, 'total_bill')
# g.map(plt.scatter, 'total_bill','tip')

# g = sns.JointGrid(data=tips,x='total_bill',y='tip') # general version of jointplot
# g.plot(sns.regplot, sns.histplot)

# sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex')
# sns.lmplot(x='total_bill',y='tip',data=tips,row='sex',col='time',aspect=1.5,height=4)

# sns.set_style('white')
# sns.despine(left=False)
# sns.set_context('notebook')

# df.plot.hist()
# df.plot.line()
# df.plot.scatter(x='X',y='Y')
# df.plot.box()
# df.plot.area()
# df.plot.bar()
# df.plot.barh()
# df.plot.density()
# df.plot.hexbin(x='X',y='Y')
# df.plot.kde()
# df.plot.pie(y='Y')

# Optional Plotly Method Imports
import plotly
import cufflinks as cf
cf.go_offline()

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.datasets import make_blobs

X = np.random.rand(30,3)
y = np.random.rand(30,1)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=101)
lm = LinearRegression()
lm.fit(X_train, y_train)
predictions = lm.predict(X_test)
metrics.mean_absolute_error(y_test, predictions)
# pd.get_dummies()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 0.21625014147926155

# %%
np.c_[0:4:0.2]
# Out:
# array([[0. ],
#        [0.2],
#        [0.4],
#        [0.6],
#        [0.8],
#        [1. ],
#        [1.2],
#        [1.4],
#        [1.6],
#        [1.8],
#        [2. ],
#        [2.2],
#        [2.4],
#        [2.6],
#        [2.8],
#        [3. ],
#        [3.2],
#        [3.4],
#        [3.6],
#        [3.8]])
